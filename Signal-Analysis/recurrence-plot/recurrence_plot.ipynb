# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)
import csv
import pandas as pd
from numpy.lib.stride_tricks import as_strided
import math
import matplotlib.cm as cm
from PIL import Image
from scipy.stats import linregress
import wave

# %%
def slenkantis_listas(a, window, step_size):
    shape = a.shape[:-1] + (a.shape[-1] - window + 1 - step_size + 1, window)
    strides = a.strides + (a.strides[-1] * step_size,)
    arr = np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)
    row_mask = (arr != 0.0).all(axis=1)
   #print(arr[row_mask,:])
    return arr[row_mask,:]

# %%
def euklidine_norma(skirtumas):
    kvadratu = [i ** 2 for i in skirtumas]
    return math.sqrt(sum(kvadratu)) 
    
def manheteno_norma(skirtumas):
    return(sum(abs(skirtumas)))

def maksimumo_norma(skirtumas):
    return(max(abs(skirtumas)))

# %%
signalas1 = pd.read_excel('ripple_signal.xlsx')
signalas1
# Out:
#           Date  Daily_High
# 0   2019-09-01        0.24
# 1   2019-09-02        0.24
# 2   2019-09-03        0.24
# 3   2019-09-04        0.24
# 4   2019-09-05        0.24
# ..         ...         ...
# 558 2021-03-21        0.46
# 559 2021-03-22        0.50
# 560 2021-03-23        0.50
# 561 2021-03-24        0.48
# 562 2021-03-25        0.44
#
# [563 rows x 2 columns]

# %%
signalas1.plot(x = 'Date', y= 'Daily_High')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
temp.plot(x = 'datetime', y= 'San Francisco')
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
tinginys.plot(x = 'Savaitė', y= 'Tinginys: (Lietuva)')
plt.savefig('Tinginys_plot.svg')

# %%
temp_signal = pd.read_csv('temperature.csv')
temp_signal
temp = temp_signal[['datetime', 'San Francisco']]
temp_signal['San Francisco'] = temp_signal['San Francisco'] - 273
temp.isnull().sum()
temp = temp.dropna()
temp = temp.head(732)
temp
# Out:
#                datetime  San Francisco
# 1    2012-10-01 13 val.     289.480000
# 2    2012-10-01 14 val.     289.474993
# 3    2012-10-01 15 val.     289.460618
# 4    2012-10-01 16 val.     289.446243
# 5    2012-10-01 17 val.     289.431869
# ..                  ...            ...
# 728  2012-10-31 20 val.     289.600000
# 729  2012-10-31 21 val.     290.480000
# 730  2012-10-31 22 val.     291.010000
# 731  2012-10-31 23 val.     291.810000
# 732   2012-11-01 0 val.     290.990000
#
# [732 rows x 2 columns]

# %%
fire_signal = pd.read_csv('California_Fire_Incidents.csv.xls')
fire_signal = fire_signal[['AcresBurned','Started']]
#fire_signal.isnull().sum()
fire = fire_signal.dropna()
fire = fire.head(401)
print(len(fire))
fire.isnull().sum()
# Out:
# 401
# AcresBurned    0
# Started        0
# dtype: int64

# %%
lietus = pd.read_csv('rainfall_1980_2016_Pakistan.csv')
lietus
# Out:
#      Rainfall - (MM)            Date
# 0           19.00350    1980_January
# 1           29.98260   1980_February
# 2           43.52350      1980_March
# 3            9.26150      1980_April
# 4           12.71970        1980_May
# ..               ...             ...
# 439         60.60610     2016_August
# 440         13.76940  2016_September
# 441          1.07552    2016_October
# 442          2.88480   2016_November
# 443          7.82298   2016_December
#
# [444 rows x 2 columns]

# %%
eurovizija = pd.read_csv('Eurovizija.csv')
eurovizija
# Out:
#         Savaitė Eurovizija: (Lietuva)
# 0    17/04/2016                     1
# 1    24/04/2016                     2
# 2    01/05/2016                    10
# 3    08/05/2016                    92
# 4    15/05/2016                    43
# ..          ...                   ...
# 256  14/03/2021                     1
# 257  21/03/2021                     1
# 258  28/03/2021                     2
# 259  04/04/2021                     1
# 260  11/04/2021                     0
#
# [261 rows x 2 columns]

# %%
tinginys = pd.read_csv('Tinginys_5metaii.csv')
tinginys
tinginys = tinginys.replace(['0'],'1')
tinginys
# Out:
#         Savaitė  Tinginys: (Lietuva)
# 0    17/04/2016                   11
# 1    24/04/2016                    3
# 2    01/05/2016                   15
# 3    08/05/2016                    9
# 4    15/05/2016                    6
# ..          ...                  ...
# 255  07/03/2021                   23
# 256  14/03/2021                   21
# 257  21/03/2021                   13
# 258  28/03/2021                   41
# 259  04/04/2021                   18
#
# [260 rows x 2 columns]

# %%
birth = pd.read_csv('daily-total-female-births.csv')
birth
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
plot = lietus.plot(x = 'Date', y= 'Rainfall - (MM)')
save
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
birth.plot(x = 'Date', y= 'Births')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# %pwd
# Out:
# 'C:\\Users\\vitam\\Desktop\\signalu analize'

# %%
tinginys.plot(x = 'Savaitė', y= 'Tinginys: (Lietuva)', color ='black', legend=False)
plt.xlabel('Savaitė')
plt.ylabel('Žodžio "Tinginys" paieškos per savaitę')
plt.xticks(rotation=45)
plt.savefig('ting_plot.png',bbox_inches='tight', dpi=300)

# %%
#signalo_reiksmes = fire['AcresBurned'].to_numpy()
signalo_reiksmes = temp['San Francisco'].to_numpy()
#signalo_reiksmes = eurovizija['Eurovizija: (Lietuva)'].to_numpy()

#signalo_reiksmes = tinginys['Tinginys: (Lietuva)'].to_numpy()
#signalo_reiksmes = testas_signalas1['Tinginys: (Lietuva)'].to_numpy()
#signalo_reiksmes = birth['Births'].to_numpy()
#signalo_reiksmes = lietus['Rainfall - (MM)'].to_numpy()
#signalo_reiksmes = signalas1['24h High (USD)'].to_numpy()
#signalo_reiksmes =signalas1['Daily_High'].to_numpy()
#signalo_reiksmes = signalo_reiksmes_raw * 100
#for i in signalo_reiksmes_raw:
#    signalo_reiksmes.append(i * 10)
#signalo_reiksmes = signalo_reiksmes.to_numpy()
signalo_reiksmes[signalo_reiksmes == 0] = 1
#signalo_reiksmes[signalo_reiksmes == '< 1'] = 1
#signalo_reiksmes = signalo_reiksmes.astype(np.float)
print(signalo_reiksmes)
#for i in range(0,len(signalo_reiksmes)):
#    print(str(i)+'\t'+str(signalo_reiksmes[i]))
# Out:
# [289.48      289.4749928 289.4606181 289.4462434 289.4318687 289.417494
#  289.4031193 289.3887446 289.3743699 289.3599952 289.3456205 289.3312458
#  289.3168711 289.3024964 289.2881217 289.273747  289.2593723 289.2449976
#  289.2306229 289.2162482 289.2018735 289.1874988 289.1731241 289.1587494
#  289.1443747 289.13      290.73      293.02      296.18      299.66
#  300.03      301.07      302.29      304.7       304.86      304.08
#  302.69      300.52      298.56      297.94      296.95      294.14
#  293.46      293.32      292.39      291.96      291.52      291.135
#  290.75      290.26      292.67      295.08      297.49      299.48
#  301.24      302.04      303.25      302.875     302.5       302.81
#  301.91      299.96      297.82      296.56      296.01      294.68
#  293.92      293.67      293.41      291.81      291.16      290.4
#  289.99      290.19      291.28      294.26      296.75      297.74
#  298.64      299.51      298.97      298.47      296.57      294.64
# ...

# %%
testas_signalas1 = tinginys.tail(110)
testas_signalas1
# Out:
#         Savaitė  Tinginys: (Lietuva)
# 150  03/03/2019                   13
# 151  10/03/2019                   13
# 152  17/03/2019                   29
# 153  24/03/2019                   17
# 154  31/03/2019                   14
# ..          ...                  ...
# 255  07/03/2021                   23
# 256  14/03/2021                   21
# 257  21/03/2021                   13
# 258  28/03/2021                   41
# 259  04/04/2021                   18
#
# [110 rows x 2 columns]

# %%
N = len(signalo_reiksmes)
D = 3 # tai nurodo po kiek elementu bus mazuose listukuose. Tiek nauju reiksmiu pridedama i lista
d = 2 # nurodo kas kelintas elementas paimamas 
M = N - (D-1) * d # i yra nuo nulio iki M, M nusako kiek listuku gausis is duomenų
y_duomenu_masyvas_pagal_dimensijas = slenkantis_listas(signalo_reiksmes, D, d)

# %%
def juoda_balta(a,b, r_reiksme):
    sk = y_duomenu_masyvas_pagal_dimensijas[a] - y_duomenu_masyvas_pagal_dimensijas[b]
    # SVARBU - norma parenkama pakeiciant funkcija zemiau esancioje eiluteje
    if maksimumo_norma(sk) < r_reiksme:
        return int(0)
    else:
        return int(255)

# %%
pav = np.zeros((M, M)) 

juodu_pikseliu_tankis = 0.99 
p = 0.8 #juodu pikseliu skaicius procentais
delta_p = 0.01 #pikseliu tankio paklaida
A = max(signalo_reiksmes) - min(signalo_reiksmes)

r_senas = A
r_naujas = p * A 

iv = pd.Interval(left=p-delta_p, right=p+delta_p, closed = 'both') # paklaidos intervalas

while juodu_pikseliu_tankis not in iv :    
    for x in  range(0,M):
        for y in range(0,M):
            kokia_spalva = juoda_balta(x,y,r_naujas)
            pav[x,y] = (kokia_spalva)
    baltu_kiekis = np.count_nonzero(pav == 255.)
    juodu_kiekis = np.count_nonzero(pav == 0.)
    print('juodu kiekis',jpt_naujas)
    jpt_naujas = juodu_kiekis / (M**2) # apskaiciuojamas juodu piksleiu kiekis procentais
    # toliau ieskom susikirtimo tasko r_naujas ir r_senas tasku su p reiksme                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    * (r_senas+r_naujas)+r_senas*jpt_naujas-r_naujas*juodu_pikseliu_tankis)/(juodu_pikseliu_tankis+jpt_naujas)
    santykis = (jpt_naujas + juodu_pikseliu_tankis)/(r_naujas + r_senas)
    r_senas = r_naujas
    r_naujas = (-santykis * r_senas+jpt_naujas+p)/santykis
    print('r_naujas',r_naujas)
    juodu_pikseliu_tankis = jpt_naujas
    print(jpt_naujas)
    if r_naujas < 0:
        print(r_naujas)
        print('NEPAVYKO, :(((((((((('
             )
        break

print(pav)
print(jpt_naujas)
print(r_naujas)
fig, ax = plt.subplots()
ax.imshow(pav, interpolation='nearest', cmap = 'gray',extent=[0, M, 0, M])
fig.savefig('tempe_maksimumo0.8_D3_d2.png', dpi=300)
plt.show()

# %% [markdown]
# #### pav = np.zeros((M, M))
#
# juodu_pikseliu_tankis = 0.99 # ar gAUNASI VIENAS SU AMPLITUDE
# p = 0.5 #juodu pikseliu skaicius procentais
# delta_p = 0.03 # galima vieno procento paklaida
# A = max(signalo_reiksmes) - min(signalo_reiksmes)
#
# r_senas = A
# r_naujas = p * A
# print('amplitude', A)
# iv = pd.Interval(left=p-delta_p, right=p+delta_p, closed = 'both') # paklaidos intervalas
#
# while juodu_pikseliu_tankis not in iv :
#     for x in  range(0,M):
#         for y in range(0,M):
#             kokia_spalva = juoda_balta(x,y,r_naujas)
#             #print(kokia_spalva)
#             pav[x,y] = (kokia_spalva)
#     baltu_kiekis = np.count_nonzero(pav == 255.)
#     juodu_kiekis = np.count_nonzero(pav == 0.)
#     jpt_naujas = juodu_kiekis / (M**2)
#     slope, intercept, r_value, p_value, std_err = linregress([r_senas,r_naujas],[juodu_pikseliu_tankis,jpt_naujas])
#     #slaupas = (jpt_naujas - juodu_pikseliu_tankis)/(r_naujas - r_senas)
#     santykis = (jpt_naujas + juodu_pikseliu_tankis)/(r_naujas + r_senas)
#     #santykis2 = (r_naujas + r_senas)/(jpt_naujas + juodu_pikseliu_tankis)
#     print('juodu piksleiu senas',juodu_pikseliu_tankis)
#     print('r_senas ', r_senas)
#     print('juodu pikseliu naujas', jpt_naujas)
#     print('r_naujas', r_naujas)
#     r_senas = r_naujas
#     r_naujas = (-santykis * r_senas+jpt_naujas+p)/santykis
#     print('r po apsk', r_naujas)
#     #r_naujas = ((p + jpt_naujas)/santykis)- r_naujas
#     #r_naujas = santykis2*(p+jpt_naujas) - r_naujas
#     #r_naujas = round(r_naujas, 2)
#     juodu_pikseliu_tankis = jpt_naujas
#     if r_naujas < 0:
#         print(r_naujas)
#         print('NEPAVYKO, :((((((((((')
#         break
#
# print(pav)
# fig, ax = plt.subplots()
# ax.imshow(pav, interpolation='nearest', cmap = 'gray',extent=[0, M, 0, M])
# #fig.savefig('')
# plt.show()
